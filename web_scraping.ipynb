# %%
import requests
import bs4
import os

import pandas as pd
import numpy as np

# %%
url = ('https://web-scraping-demo.zgulde.net/people')
response = requests.get(url)
html = response.text
soup = bs4.BeautifulSoup(html)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Example People Page</title>
# <link href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css" rel="stylesheet"/>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.4.1/font/bootstrap-icons.css" rel="stylesheet"/>
# </head>
# <body class="mx-auto max-w-screen-lg pb-32">
# <h1 class="my-5 text-4xl text-center">People</h1>
# <div class="my-5 text-red-800 px-5 py-3 bg-red-100 font-bold">
# <p>
# <i class="bi bi-exclamation-circle text-xl"></i>
#         All data on this page is strictly for demonstration purposes and fake.
#     </p>
# </div>
# <div class="grid grid-cols-2 gap-x-12 gap-y-16" id="people">
# <div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
# ...

# %%
people_container = soup.select('.grid.grid-cols-2.gap-x-12')[0]
people_container
# Out:
# <div class="grid grid-cols-2 gap-x-12 gap-y-16" id="people">
# <div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
# <h2 class="text-2xl text-purple-800 name col-span-full border-b">Joshua Scott</h2>
# <p class="quote col-span-full px-5 py-5 text-center text-gray-500">
#             "User-friendly heuristic Internet solution"
#         </p>
# <div class="grid grid-cols-9">
# <i class="bi bi-envelope-fill text-purple-800"></i>
# <p class="email col-span-8">thompsonjason@martin-roberts.com</p>
# <i class="bi bi-telephone-fill text-purple-800"></i>
# <p class="phone col-span-8">812.224.5995x4480</p>
# </div>
# <div class="address grid grid-cols-9">
# <i class="bi bi-geo-fill text-purple-800"></i>
# <p class="col-span-8">
#                 4744 Mcclure Rue <br/>
#                 Markhaven, MO 18657
#             </p>
# </div>
# </div>
# ...

# %%
people = people_container.select('.grid.grid-cols-2.gap-x-3')
people
# Out:
# [<div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
#  <h2 class="text-2xl text-purple-800 name col-span-full border-b">Joshua Scott</h2>
#  <p class="quote col-span-full px-5 py-5 text-center text-gray-500">
#              "User-friendly heuristic Internet solution"
#          </p>
#  <div class="grid grid-cols-9">
#  <i class="bi bi-envelope-fill text-purple-800"></i>
#  <p class="email col-span-8">thompsonjason@martin-roberts.com</p>
#  <i class="bi bi-telephone-fill text-purple-800"></i>
#  <p class="phone col-span-8">812.224.5995x4480</p>
#  </div>
#  <div class="address grid grid-cols-9">
#  <i class="bi bi-geo-fill text-purple-800"></i>
#  <p class="col-span-8">
#                  4744 Mcclure Rue <br/>
#                  Markhaven, MO 18657
#              </p>
#  </div>
#  </div>,
# ...

# %%
len(people)
# Out:
# 10

# %%
person = people[0]
print(person.prettify())
# Out:
# <div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
#  <h2 class="text-2xl text-purple-800 name col-span-full border-b">
#   Joshua Scott
#  </h2>
#  <p class="quote col-span-full px-5 py-5 text-center text-gray-500">
#   "User-friendly heuristic Internet solution"
#  </p>
#  <div class="grid grid-cols-9">
#   <i class="bi bi-envelope-fill text-purple-800">
#   </i>
#   <p class="email col-span-8">
#    thompsonjason@martin-roberts.com
#   </p>
#   <i class="bi bi-telephone-fill text-purple-800">
#   </i>
#   <p class="phone col-span-8">
#    812.224.5995x4480
#   </p>
#  </div>
#  <div class="address grid grid-cols-9">
#   <i class="bi bi-geo-fill text-purple-800">
#   </i>
#   <p class="col-span-8">
#    4744 Mcclure Rue
#    <br/>
#    Markhaven, MO 18657
#   </p>
#  </div>
# </div>

# %%
name = person.find('h2').text

# %%
quote = person.find_all('p')[0].text
quote
# Out:
# '\n            "User-friendly heuristic Internet solution"\n        '

# %%
email = person.find_all('p')[1].text
email
# Out:
# 'thompsonjason@martin-roberts.com'

# %%
phone = person.find_all('p')[2].text
phone
# Out:
# '812.224.5995x4480'

# %%
address = person.find_all('p')[3].text
address
# Out:
# '\n                4744 Mcclure Rue \n                Markhaven, MO 18657\n            '

# %%
def process_people(person):
    name = person.find('h2').text
    quote = person.find_all('p')[0].text.strip()
    email = person.find_all('p')[1].text
    phone_and_ext = person.find_all('p')[2].text
    address = person.find_all('p')[3].text.strip()
    
    return {
        "name": name,
        "quote": quote,
        "email": email,
        "phone_and_ext": phone,
        "address": address
    }

# %%
df = pd.DataFrame([process_people(person) for person in people])
df
# Out:
#              name                                        quote  \
# 0    Joshua Scott  "User-friendly heuristic Internet solution"
# 1   Jacob Carlson                   "Visionary optimal matrix"
# 2     Erica Davis     "Mandatory object-oriented service-desk"
# 3  Benjamin Moore                      "Reactive static model"
# 4     James Walls           "Reduced encompassing parallelism"
# 5   Troy Cummings                  "Seamless 24hour groupware"
# 6   Steve Johnson          "Advanced human-resource groupware"
# 7     Bruce Burns      "Focused solution-oriented methodology"
# 8    Lisa Robbins     "Re-engineered logistical system engine"
# 9     Eric Butler         "Enhanced zero tolerance neural-net"
#
#                                    email      phone_and_ext  \
# 0       thompsonjason@martin-roberts.com  812.224.5995x4480
# 1                  carteramber@hood.info  812.224.5995x4480
# 2         ryanknox@johnson-rodriguez.com  812.224.5995x4480
# ...

# %% [markdown]
# ## Codeup Blog Articles
#
# ### Scrape the article text from the following pages:
#
# - https://codeup.com/codeups-data-science-career-accelerator-is-here/
# - https://codeup.com/data-science-myths/
# - https://codeup.com/data-science-vs-data-analytics-whats-the-difference/
# - https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/
# - https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/
#
# ### Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:
# ```
# {
#     'title': 'the title of the article',
#     'content': 'the full text content of the article'
# }
# ```
# ### Plus any additional properties you think might be helpful.
#
# ## **Bonus:**
#
# ### Scrape the text of all the articles linked on codeup's blog page.

# %%
url = 'https://codeup.com/codeups-data-science-career-accelerator-is-here/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)
html = response.text
soup = bs4.BeautifulSoup(html)

# %%
career_container = soup.select('.container')[0]

# %%
body = career_container.find(itemprop='text').text
body
# Out:
# 'The rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America.\nData Science is a method of providing actionable intelligence from data.\xa0The data revolution has hit San Antonio,\xa0resulting in an explosion in Data Scientist positions\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\xa0We built a program to specifically meet the growing demands of this industry.\nOur program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Stude
# ...

# %%
career = {
    'title': career_container.find('h1').text,
    'body': body
}

# %%
blog_df = pd.DataFrame(career, index=[0])

# %%
url = 'https://codeup.com/data-science-myths/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)
html = response.text
soup = bs4.BeautifulSoup(html)

# %%
myth_container = soup.select('.container')[0]

# %%
title = myth_container.find('h1').text
body = myth_container.find(itemprop='text').text
body
# Out:
# 'By Dimitri Antoniou and Maggie Giust\nData Science, Big Data, Machine Learning, NLP, Neural Networks…these buzzwords have rapidly spread into mainstream use over the last few years. Unfortunately, definitions are varied and sources of truth are limited. Data Scientists are in fact not magical unicorn wizards who can snap their fingers and turn a business around! Today, we’ll take a cue from our favorite Mythbusters to tackle some common myths and misconceptions in the field of Data Science.\n\xa0\nMyth #1: Data Science = Statistics\nAt first glance, this one doesn’t sound unreasonable. Statistics is defined as, “A branch of mathematics dealing with the collection, analysis, interpretation, and presentation of masses of numerical data.” That sounds a lot like our definition of Data Science: a method of drawing actionable intelligence from data. \nIn truth, statistics is actually one small piece of Data Science. As our Senior Data Scientist puts it, “Statistics forces us to make assum
# ...

# %%
myth = {
    'title': title,
    'body': body
}

# %%
myth_df = pd.DataFrame(myth, index=[1])

# %%
blog_df = pd.concat([blog_df, myth_df], axis=0)

# %%
url = 'https://codeup.com/data-science-vs-data-analytics-whats-the-difference/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)
html = response.text
soup = bs4.BeautifulSoup(html)

# %%
vers_container = soup.select('.container')[0]

# %%
title = vers_container.find('h1').text
body = vers_container.find(itemprop='text').text
body
# Out:
# 'By Dimitri Antoniou\nA week ago, Codeup launched our immersive Data Science career accelerator! With our first-class kicking off in February and only 25 seats available, we’ve been answering a lot of questions from prospective students. One, in particular, has come up so many times we decided to dedicate a blog post to it. What is the difference between data science and data analytics?\nFirst, let’s define some of our terms! Take a look at this blog to understand what Data Science is. In short, it is a method of turning raw data into action, leading to the desired outcome. Big Data refers to data sets that are large and complex, usually exceeding the capacity of computers and normal processing power to deal with. Machine Learning is the process of ‘learning’ underlying patterns of data in order to automate the extraction of intelligence from that data.\n\xa0\n\xa0\nNow, let’s look at the data pipeline that data scientists work through to reach the actionable insights and outcomes we
# ...

# %%
vers = {
    'title': title,
    'body': body
}

# %%
vers_df = pd.DataFrame(vers, index=[2])

# %%
blog_df = pd.concat([blog_df, vers_df], axis=0)
blog_df
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is Here!
# 1                                 Data Science Myths
# 2  Data Science VS Data Analytics: What’s The Dif...
#
#                                                 body
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie Giust\nData Sci...
# 2  By Dimitri Antoniou\nA week ago, Codeup launch...

# %%
url = 'https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)
html = response.text
soup = bs4.BeautifulSoup(html)

# %%
tip = soup.select('.container')[0]

# %%
title = tip.find('h1').text
body = tip.find(itemprop='text').text
tip.time.text
# Out:
# 'August 14, 2018'

# %%
tip = {
    'title': title,
    'body': body
}

# %%
tips_df = pd.DataFrame(tip, index=[3])

# %%
blog_df = pd.concat([blog_df, tips_df], axis=0)
blog_df
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is Here!
# 1                                 Data Science Myths
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3        10 Tips to Crush It at the SA Tech Job Fair
#
#                                                 body
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie Giust\nData Sci...
# 2  By Dimitri Antoniou\nA week ago, Codeup launch...
# 3  SA Tech Job Fair\nThe third bi-annual San Anto...

# %%
blog_df.reset_index(drop=True)
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is Here!
# 1                                 Data Science Myths
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3        10 Tips to Crush It at the SA Tech Job Fair
#
#                                                 body
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie Giust\nData Sci...
# 2  By Dimitri Antoniou\nA week ago, Codeup launch...
# 3  SA Tech Job Fair\nThe third bi-annual San Anto...

# %%
urls = ['https://codeup.com/codeups-data-science-career-accelerator-is-here/', \
        'https://codeup.com/data-science-myths/', \
        'https://codeup.com/data-science-vs-data-analytics-whats-the-difference/', \
        'https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/', \
        'https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/']

# %%
# This function is commented out below

def codeup_blogs(urls):
    blog_df = pd.DataFrame(columns=['title', 'body'])
    for url in urls:
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
        response = requests.get(url, headers=headers)
        html = response.text
        soup = bs4.BeautifulSoup(html)
        container = soup.select('.container')[0]
        title = container.find('h1').text
        body = container.find(itemprop='text').text
        container_dict = {
                    'title': title,
                    'body': body
                        }
        container_df = pd.DataFrame(container_dict,index=[0])
        blog_df = pd.concat([blog_df, container_df], axis=0)
        
    return blog_df.drop_duplicates().reset_index(drop=True)

# %%
codeup_blogs(urls)
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is Here!
# 1                                 Data Science Myths
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3        10 Tips to Crush It at the SA Tech Job Fair
# 4  Competitor Bootcamps Are Closing. Is the Model...
#
#                                                 body
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie Giust\nData Sci...
# 2  By Dimitri Antoniou\nA week ago, Codeup launch...
# 3  SA Tech Job Fair\nThe third bi-annual San Anto...
# 4  Competitor Bootcamps Are Closing. Is the Model...

# %%
url = 'https://codeup.com/blog/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)
html = response.text
soup = bs4.BeautifulSoup(html)

# %%
soup.select('a.jet-listing-dynamic-link__link')
# Out:
# [<a class="jet-listing-dynamic-link__link" href="https://codeup.com/meet-the-new-codeup-coo-stephen-noteboom/"><span class="jet-listing-dynamic-link__label">Meet the new Codeup COO, Stephen Noteboom!</span></a>,
#  <a class="jet-listing-dynamic-link__link" href="https://codeup.com/meet-the-new-codeup-coo-stephen-noteboom/"><span class="jet-listing-dynamic-link__label">Read More</span></a>,
#  <a class="jet-listing-dynamic-link__link" href="https://codeup.com/how-i-went-from-codeup-to-business-owner/"><span class="jet-listing-dynamic-link__label">How I Went From Codeup to Business Owner</span></a>,
#  <a class="jet-listing-dynamic-link__link" href="https://codeup.com/how-i-went-from-codeup-to-business-owner/"><span class="jet-listing-dynamic-link__label">Read More</span></a>,
#  <a class="jet-listing-dynamic-link__link" href="https://codeup.com/coding-is-for-women/"><span class="jet-listing-dynamic-link__label">Coding is for Women</span></a>,
# ...

# %%
urls = []
for a in soup.select('a.jet-listing-dynamic-link__link', href=True):
    urls.append(a['href'])
    urls = list(set(urls))

urls
# Out:
# ['https://codeup.com/alumni-spotlight-stefanie-young-and-lorne-barfield/',
#  'https://codeup.com/how-i-went-from-codeup-to-business-owner/',
#  'https://codeup.com/transition-into-data-science/',
#  'https://codeup.com/thinking-about-a-bootcamp-to-transition-careers/',
#  'https://codeup.com/build-your-career-in-tech/',
#  'https://codeup.com/how-i-paid-43-for-my-codeup-tuition/',
#  'https://codeup.com/data-science-in-the-real-world/',
#  'https://codeup.com/fight-covid-19-data-challenge/',
#  'https://codeup.com/career-in-data-science/',
#  'https://codeup.com/alumni-spotlight-mary-kaitlin-mk-warren/',
#  'https://codeup.com/data-science-without-a-degree/',
#  'https://codeup.com/5-hiring-trends-in-software-development/',
#  'https://codeup.com/from-the-service-industry-to-software-development/',
#  'https://codeup.com/how-codeup-paid-off-for-both-employee-and-employer/',
#  'https://codeup.com/from-cooking-steaks-to-cooking-code/',
# ...

# %%
def codeup_blogs(urls):
    '''
    
    Description:
    -----------
    This is a helper function to collect the codeup blogs
    
    Parameters:
    ----------
    urls: list
        List of urls as strings
    
    '''
    # create blank dataframe to hold results
    blog_df = pd.DataFrame(columns=['title', 'body'])
    
    # loop that creates a list of urls
    for url in urls:
        
        # standard lines to create a soup variable 
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
        response = requests.get(url, headers=headers)
        html = response.text
        soup = bs4.BeautifulSoup(html)
        
        # create a container
        container = soup.select('.container')[0]
        # within the container the h1 element = the title
        title = container.find('h1').text
        # collects the body text
        body = container.find(itemprop='text').text
        # create a dictionary that holds the title and body
        container_dict = {
                    'title': title,
                    'body': body,
                        }
        # converts dictionary into a dataframe
        container_df = pd.DataFrame(container_dict,index=[0])
        # concats the container_df to the blog_df created earlier
        blog_df = pd.concat([blog_df, container_df], axis=0)
    
    # returns the blog_df with no duplicates and a reset index
    return blog_df.drop_duplicates().reset_index(drop=True)




def all_codeup_blogs():
    '''
    
    Description:
    -----------
    This function collects the title and body of ALL codeup blogs
    
    '''
    # hard coding the codeup blog website
    url = 'https://codeup.com/blog/'
    
    # standard lines to create a soup variable 
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    response = requests.get(url, headers=headers)
    html = response.text
    soup = bs4.BeautifulSoup(html)
    
    # empty urls list
    urls = []
    # loop that creates the urls list
    for a in soup.select('a.jet-listing-dynamic-link__link', href=True):
        # add url to urls list
        urls.append(a['href'])
        # deletes duplicates and keeps unique values
        urls = list(set(urls))
    
    # runs the codeup_blogs with the urls created in the loop
    blogs_df = codeup_blogs(urls)
    
    # returns the blogs_df
    return blogs_df

# %%
df = all_codeup_blogs()

# %%
df.head()
# Out:
#                                                title  \
# 0  Alumni Spotlight: Stefanie Young and Lorne Bar...
# 1           How I Went From Codeup to Business Owner
# 2     What is the Transition into Data Science Like?
# 3   Thinking About a Bootcamp to Transition Careers?
# 4     Build Your Career in Tech: Advice from Alumni!
#
#                                                 body
# 0  Alumni Spotlight: Stefanie Young and Lorne Bar...
# 1  Out of college, I was a bit of a mess. That’s ...
# 2  Alumni Katy Salts and Brandi Reger joined us a...
# 3  Five Questions to Ask Yourself When Thinking A...
# 4  Bryan Walsh, Codeup Web Development alum, and ...

# %% [markdown]
# ## News Articles
#
# ### We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# ### Write a function that scrapes the news articles for the following topics:
#
# #### - Business
# #### - Sports
# #### - Technology
# #### - Entertainment
#
# ### The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
# ```
# {
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }
# ```

# %%
url = ('https://inshorts.com/en/read/business')
response = requests.get(url)
html = response.text
soup = bs4.BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
business_container = soup.select('.card-stack')[0]
business_container
# Out:
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/air-india-pilots-demand-vaccination-on-priority-say-well-stop-work-1620124012903" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Kiran Khatri" itemprop="name"></span>
# </span>
# <span content="Air India pilots demand vaccination on priority, say 'We'll stop work'" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/4_tue/img_1620121481945_470.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# ...

# %%
business_articles = business_container.select(".news-card.z-depth-1")

# %%
business_article = business_articles[0]

# %%
author = business_article.find(class_="author").text

# %%
body = business_article.find(itemprop="articleBody").text

# %%
title = business_article.find(itemprop="headline").text

# %%
time = business_article.find(class_="time").text

# %%
date = business_article.find(clas="date").text

# %%
def inshorts_articles(business_article):
    return {
        'title': business_article.find(itemprop="headline").text,
        'body': business_article.find(itemprop="articleBody").text,
        'author': business_article.find(class_="author").text,
        'date_modified': business_article.find(clas="date").text,
        'time_modified': business_article.find(class_="time").text,
    }

# %%
inshorts_articles(business_articles[7])

# %%
business_df = pd.DataFrame([inshorts_articles(business_article) for business_article in business_articles])

# %%
url = 'https://inshorts.com/en/read/sports'
response = requests.get(url)
html = response.text
soup = bs4.BeautifulSoup(html)

# %%
sport_container = soup.select('.card-stack')[0]

# %%
sport_articles = sport_container.select('.news-card.z-depth-1')

# %%
sport_article = sport_articles[0]
sport_article

# %%
inshorts_articles(sport_articles[9])

# %%
sport_df = pd.DataFrame([inshorts_articles(sport_article) for sport_article in sport_articles])
sport_df

# %%
def get_soup(url):
    response = requests.get(url)
    html = response.text
    soup = bs4.BeautifulSoup(html)
    
    return soup

# %%
url = 'https://inshorts.com/en/read/technology'
soup = get_soup(url)
soup

# %%
tech_container = soup.select('.card-stack')[0]

# %%
tech_articles = tech_container.select('.news-card.z-depth-1')

# %%
tech_article = tech_articles[0]

# %%
tech_df = pd.DataFrame([inshorts_articles(tech_article) for tech_article in tech_articles])
tech_df

# %%
url = 'https://inshorts.com/en/read/entertainment'
soup = get_soup(url)
soup

# %%
ent_container = soup.select('.card-stack')[0]

# %%
ent_articles = ent_container.select('.news-card.z-depth-1')

# %%
ent_article = ent_articles[0]
ent_article

# %%
ent_df = pd.DataFrame([inshorts_articles(ent_article) for ent_article in ent_articles])
ent_df

# %%
base_url = 'https://inshorts.com/en/read/'
categories = ['india',
'business',
'sports',
'world',
'politics',
'technology',
'startup',
'entertainment',
'miscellaneous',
'hatke',
'science',
'automobile']

# %%
urls = [base_url + cat for cat in category]
urls
# Out:
# ['https://inshorts.com/en/read/india',
#  'https://inshorts.com/en/read/business',
#  'https://inshorts.com/en/read/sports',
#  'https://inshorts.com/en/read/world',
#  'https://inshorts.com/en/read/politics',
#  'https://inshorts.com/en/read/technology',
#  'https://inshorts.com/en/read/startup',
#  'https://inshorts.com/en/read/entertainment',
#  'https://inshorts.com/en/read/miscellaneous',
#  'https://inshorts.com/en/read/hatke',
#  'https://inshorts.com/en/read/science',
#  'https://inshorts.com/en/read/automobile']

# %%
def inshorts_articles(article):
    return {
        'title': article.find(itemprop="headline").text,
        'body': article.find(itemprop="articleBody").text,
        'author': article.find(class_="author").text,
        'date_modified': article.find(clas="date").text,
        'time_modified': article.find(class_="time").text,
    }


def get_inshorts_articles(categories):
    
    inshort_df = pd.DataFrame(columns=['title', 'body','author','date_modified','time_modified'])
    base_url = 'https://inshorts.com/en/read/'
    
    for cat in categories:
        url = str(base_url + cat)
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
        response = requests.get(url, headers=headers)
        html = response.text
        soup = bs4.BeautifulSoup(html)
        container = soup.select('.card-stack')[0]
        articles = container.select('.news-card.z-depth-1')
        article = articles[0]
        
        # converts dictionary into a dataframe
        article_df = pd.DataFrame([inshorts_articles(article) for article in articles])
    
        # concats the container_df to the blog_df created earlier
        inshort_df = pd.concat([inshort_df, article_df], axis=0)
    
    return inshort_df.reset_index(drop=True)

# %%
inshorts_df = get_inshorts_articles(categories)

# %%
inshorts_df.head()
# Out:
#                                                title  \
# 0          Infosys Gifts Sikka Shares Worth Rs 8.2cr
# 1  AAP drops Rajouri Garden candidate, a week bef...
# 2  Nigerian weightlifter in dope net, India may gain
# 3    Samsung launches Galaxy Star 2 Plus at Rs.7,335
# 4  Indian Navy gets VLF, easy communication with ...
#
#                                                 body            author  \
# 0  In a regulatory filing to the BSE on Friday, I...      Tanya Mathur
# 1  Only a week before Delhi Assembly polls, Aam A...  Shashank Shekhar
# 2  India may move up after Nigerian weightlifter ...     Sumedha Sehra
# 3  Samsung has unveiled the Galaxy start 2 Plus s...     Sumedha Sehra
# 4  The Indian navy has a new communication system...     Sumedha Sehra
#
#            date_modified time_modified
# 0     24 Aug 2014,Sunday      10:55 pm
# 1  27 Nov 2013,Wednesday      02:43 am
# 2    29 Jul 2014,Tuesday      06:47 pm
# 3    29 Jul 2014,Tuesday      06:52 pm
# ...
